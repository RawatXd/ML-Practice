# %%
base = 10 
height = 6 

area = base * height

# %%
area
# Out:
# 60

# %%
type(area)
# Out:
# int

# %%
area = (base*height)/2

# %%
area
# Out:
# 30.0

# %%
type(area)
# Out:
# float

# %%
a = 8
b = 4 
a+b
# Out:
# 12

# %%
a*b
# Out:
# 32

# %%
a/b
# Out:
# 2.0

# %%
a%b
# Out:
# 0

# %%
10+2*3
# Out:
# 16

# %%
1e4
# Out:
# 10000.0

# %%
1e-3
# Out:
# 0.001

# %%
food = "120.31"
fruit = "111.21"
eat = food + fruit
eat
# Out:
# '120.31111.21'

# %%
eat = float(food) + float(fruit)
eat
# Out:
# 231.51999999999998

# %%
import math

math.floor(3.7)
# Out:
# 3
