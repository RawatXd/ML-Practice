# %%
base = 10 
height = 6 

area = base * height

# %%
area
# Out:
# 60

# %%
type(area)
# Out:
# int

# %%
area = (base*height)/2

# %%
area
# Out:
# 30.0

# %%
type(area)
# Out:
# float

# %%
a = 8
b = 4 
a+b
