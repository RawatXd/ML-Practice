# %%
import csv

def calculate_rating_stats(data,industry = None):
    rating = []
    for row in data:
        if row[3]!= 'NULL' and (not industry or row[1]==industry):
            rating.append(float(row[3]))
    max_rating = max(rating)
    min_rating = min(rating)
    avg_rating = sum(rating)/len(rating)
    return max_rating,min_rating,avg_rating

with open("movies.csv") as f:
   data  = list(csv.reader(f))
   header = data[0]
   data = data[1:]

max_rating,min_rating,avg_rating = calculate_rating_stats(data)
print(f"All Records : Min Rating = {min_rating}, Max Rating = {max_rating} and Average Rating = {avg_rating}")

max_rating,min_rating,avg_rating = calculate_rating_stats(data,industry = "Bollywood")
print(f"Bollywood : Min Rating = {min_rating}, Max Rating = {max_rating} and Average Rating = {avg_rating}")


max_rating,min_rating,avg_rating = calculate_rating_stats(data,industry = "Hollywood")
print(f"Hollywood : Min Rating = {min_rating}, Max Rating = {max_rating} and Average Rating = {avg_rating}")
# Out:
# All Records : Min Rating = 1.9, Max Rating = 9.3 and Average Rating = 7.919444444444445
# Bollywood : Min Rating = 1.9, Max Rating = 8.4 and Average Rating = 7.65625
# Hollywood : Min Rating = 6.8, Max Rating = 9.3 and Average Rating = 8.129999999999999

# %%
import pandas as pd

df = pd.read_csv("movies.csv")
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df.tail(4)
# Out:
#                         title   industry  release_year  imdb_rating  \
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
df.sample(4)
# Out:
#                                  title   industry  release_year  imdb_rating  \
# 21         Dilwale Dulhania Le Jayenge  Bollywood          1995          8.0
# 30                   Bajrangi Bhaijaan  Bollywood          2015          8.1
# 3                      Thor: Ragnarok   Hollywood          2017          7.9
# 19  Captain America: The First Avenger  Hollywood          2011          6.9
#
#                studio  budget  revenue      unit currency language
# 21     Yash Raj Films   400.0   2000.0  Millions      INR    Hindi
# 30  Salman Khan Films   900.0  11690.0  Millions      INR    Hindi
# 3      Marvel Studios   180.0    854.0  Millions      USD  English
# 19     Marvel Studios   216.7    370.6  Millions      USD  English

# %%
df.shape
# Out:
# (37, 10)

# %%
df.imdb_rating
# Out:
# 0     8.3
# 1     7.0
# 2     6.8
# 3     7.9
# 4     6.8
# 5     9.3
# 6     8.6
# 7     8.0
# 8     8.5
# 9     7.9
# 10    8.6
# 11    7.8
# 12    9.2
# 13    9.0
# 14    9.0
# 15    8.2
# 16    8.5
# 17    8.4
# 18    8.4
# 19    6.9
# 20    7.8
# 21    8.0
# 22    8.4
# 23    7.4
# 24    7.2
# 25    8.3
# 26    8.1
# 27    8.1
# 28    NaN
# 29    8.3
# 30    8.1
# 31    1.9
# 32    8.4
# 33    8.4
# 34    7.6
# 35    8.0
# 36    8.0
# Name: imdb_rating, dtype: float64

# %%
print(df.imdb_rating.min()),print(df.imdb_rating.max()),print(df.imdb_rating.mean())
# Out:
# 1.9
# 9.3
# 7.919444444444445
# (None, None, None)

# %%
df_b = df[df.industry == "Hollywood"]
df_h = df[df.industry == "Bollywood"]

df_b.imdb_rating.min(),df_b.imdb_rating.max(),df_b.imdb_rating.mean()
# Out:
# (np.float64(6.8), np.float64(9.3), np.float64(8.130000000000003))
