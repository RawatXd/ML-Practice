# %%
can = "Soda"

# %%
can
# Out:
# 'Soda'

# %%
print(can)
# Out:
# Soda

# %%
type(can)
# Out:
# str

# %%
samosa = 12 
seb = 15

# %%
total = samosa + seb
total
# Out:
# 27

# %%
type(total)
# Out:
# int

# %%
type(samosa)
# Out:
# int

# %%
samosa = "apple"
samosa
# Out:
# 'apple'

# %%
id(samosa)
# Out:
# 1195972643936

# %%
def = "Hello"
# Out:
#   Cell In[16], line 1
#     def = "Hello"
#         ^
# SyntaxError: invalid syntax
